# %%
import requests
import pandas as pd
from datetime import datetime

url = 'https://fapi.binance.com/futures/data/openInterestHist'
params = {
    'symbol': 'BTCUSDT',
    'period': '1d',
    'limit': 500     # Maximum limit is 500
}

response = requests.get(url, params=params)


data = response.json()
data
# Out:
# [{'symbol': 'BTCUSDT',
#   'sumOpenInterest': '86084.84200000',
#   'sumOpenInterestValue': '5842012173.52480300',
#   'timestamp': 1722124800000},
#  {'symbol': 'BTCUSDT',
#   'sumOpenInterest': '85860.25800000',
#   'sumOpenInterestValue': '5857180798.25211050',
#   'timestamp': 1722211200000},
#  {'symbol': 'BTCUSDT',
#   'sumOpenInterest': '84865.25400000',
#   'sumOpenInterestValue': '5665370847.58556800',
#   'timestamp': 1722297600000},
#  {'symbol': 'BTCUSDT',
#   'sumOpenInterest': '82994.07300000',
#   'sumOpenInterestValue': '5490838073.23620000',
#   'timestamp': 1722384000000},
#  {'symbol': 'BTCUSDT',
#   'sumOpenInterest': '82570.40400000',
#   'sumOpenInterestValue': '5334196725.12720000',
#   'timestamp': 1722470400000},
#  {'symbol': 'BTCUSDT',
#   'sumOpenInterest': '87192.05200000',
#   'sumOpenInterestValue': '5696160845.90280000',
#   'timestamp': 1722556800000},
#  {'symbol': 'BTCUSDT',
#   'sumOpenInterest': '87796.48700000',
#   'sumOpenInterestValue': '5398052867.76190000',
#   'timestamp': 1722643200000},
#  {'symbol': 'BTCUSDT',
#   'sumOpenInterest': '85283.12600000',
#   'sumOpenInterestValue': '5175372388.05960000',
#   'timestamp': 1722729600000},
#  {'symbol': 'BTCUSDT',
#   'sumOpenInterest': '88098.46400000',
#   'sumOpenInterestValue': '5121964528.69245150',
#   'timestamp': 1722816000000},
#  {'symbol': 'BTCUSDT',
#   'sumOpenInterest': '75212.50300000',
#   'sumOpenInterestValue': '4060141944.60171130',
#   'timestamp': 1722902400000},
#  {'symbol': 'BTCUSDT',
#   'sumOpenInterest': '76846.83000000',
#   'sumOpenInterestValue': '4304090775.54613700',
#   'timestamp': 1722988800000},
#  {'symbol': 'BTCUSDT',
#   'sumOpenInterest': '76977.23400000',
#   'sumOpenInterestValue': '4241668827.37860000',
#   'timestamp': 1723075200000},
#  {'symbol': 'BTCUSDT',
#   'sumOpenInterest': '74964.25200000',
#   'sumOpenInterestValue': '4622448174.96502400',
#   'timestamp': 1723161600000},
#  {'symbol': 'BTCUSDT',
#   'sumOpenInterest': '71916.70500000',
#   'sumOpenInterestValue': '4373161339.33350000',
#   'timestamp': 1723248000000},
#  {'symbol': 'BTCUSDT',
#   'sumOpenInterest': '71072.42800000',
#   'sumOpenInterestValue': '4327987229.99228400',
#   'timestamp': 1723334400000},
#  {'symbol': 'BTCUSDT',
#   'sumOpenInterest': '70092.77700000',
#   'sumOpenInterestValue': '4113969379.01640000',
#   'timestamp': 1723420800000},
#  {'symbol': 'BTCUSDT',
#   'sumOpenInterest': '68490.55900000',
#   'sumOpenInterestValue': '4063106525.89240000',
#   'timestamp': 1723507200000},
#  {'symbol': 'BTCUSDT',
#   'sumOpenInterest': '72127.82400000',
#   'sumOpenInterestValue': '4367734979.36916400',
#   'timestamp': 1723593600000},
#  {'symbol': 'BTCUSDT',
#   'sumOpenInterest': '78050.79100000',
#   'sumOpenInterestValue': '4577530595.64710000',
#   'timestamp': 1723680000000},
#  {'symbol': 'BTCUSDT',
#   'sumOpenInterest': '83767.53500000',
#   'sumOpenInterestValue': '4817913569.94713200',
#   'timestamp': 1723766400000},
#  {'symbol': 'BTCUSDT',
#   'sumOpenInterest': '82133.26700000',
#   'sumOpenInterestValue': '4833953429.28500000',
#   'timestamp': 1723852800000},
#  {'symbol': 'BTCUSDT',
#   'sumOpenInterest': '82618.62200000',
#   'sumOpenInterestValue': '4913197260.54480000',
#   'timestamp': 1723939200000},
#  {'symbol': 'BTCUSDT',
#   'sumOpenInterest': '82695.12700000',
#   'sumOpenInterestValue': '4828576735.04270000',
#   'timestamp': 1724025600000},
#  {'symbol': 'BTCUSDT',
#   'sumOpenInterest': '79748.87800000',
#   'sumOpenInterestValue': '4737091328.08780000',
#   'timestamp': 1724112000000},
#  {'symbol': 'BTCUSDT',
#   'sumOpenInterest': '82720.66100000',
#   'sumOpenInterestValue': '4879501534.86970000',
#   'timestamp': 1724198400000},
#  {'symbol': 'BTCUSDT',
#   'sumOpenInterest': '85607.45400000',
#   'sumOpenInterestValue': '5232327588.48000000',
#   'timestamp': 1724284800000},
#  {'symbol': 'BTCUSDT',
#   'sumOpenInterest': '83676.72400000',
#   'sumOpenInterestValue': '5049881925.72760000',
#   'timestamp': 1724371200000},
#  {'symbol': 'BTCUSDT',
#   'sumOpenInterest': '86666.88200000',
#   'sumOpenInterestValue': '5548405118.95180000',
#   'timestamp': 1724457600000},
#  {'symbol': 'BTCUSDT',
#   'sumOpenInterest': '87051.13600000',
#   'sumOpenInterestValue': '5581875784.25770900',
#   'timestamp': 1724544000000},
#  {'symbol': 'BTCUSDT',
#   'sumOpenInterest': '87953.83400000',
#   'sumOpenInterestValue': '5646631310.32963100',
#   'timestamp': 1724630400000},
#  {'symbol': 'BTCUSDT',
#   'sumOpenInterest': '84295.24200000',
#   'sumOpenInterestValue': '5294951304.22399800',
#   'timestamp': 1724716800000}]
