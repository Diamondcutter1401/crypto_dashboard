# %%
import csv
import pandas as pd
import matplotlib.pyplot as plt

btc_df = pd.read_csv('btc_price_binance.csv')
open_interest_df = pd.read_csv('open_interest_binance.csv')
btc_df.rename(columns={'Close':'BTC Price','Open Time':'Date'}, inplace=True)

# %%
btc_df
# Out:
#            Date      Open      High       Low  BTC Price         Volume  \
# 0    2021-12-02  57184.07  57375.47  55777.77   56480.34   37574.059760
# 1    2021-12-03  56484.26  57600.00  51680.00   53601.05   58927.690270
# 2    2021-12-04  53601.05  53859.10  42000.30   49152.47  114203.373748
# 3    2021-12-05  49152.46  49699.05  47727.21   49396.33   45580.820120
# 4    2021-12-06  49396.32  50891.11  47100.00   50441.92   58571.215750
# ..          ...       ...       ...       ...        ...            ...
# 995  2024-08-23  60375.83  64955.00  60342.14   64037.24   38118.070890
# 996  2024-08-24  64037.24  64494.50  63531.00   64157.01   15857.156160
# 997  2024-08-25  64157.02  65000.00  63773.27   64220.00   12305.479770
# 998  2024-08-26  64219.99  64481.00  62800.00   62834.00   19470.052760
# 999  2024-08-27  62834.00  63212.00  62657.00   62755.01    5682.179900
#
#      Close Time  Quote Asset Volume  Number of Trades  \
# ...

# %%
open_interest_df
# Out:
#           Date  Open Interest  Open Interest Value
# 0   2024-07-28      86084.842         5.842012e+09
# 1   2024-07-29      85860.258         5.857181e+09
# 2   2024-07-30      84865.254         5.665371e+09
# 3   2024-07-31      82994.073         5.490838e+09
# 4   2024-08-01      82570.404         5.334197e+09
# 5   2024-08-02      87192.052         5.696161e+09
# 6   2024-08-03      87796.487         5.398053e+09
# 7   2024-08-04      85283.126         5.175372e+09
# 8   2024-08-05      88098.464         5.121965e+09
# 9   2024-08-06      75212.503         4.060142e+09
# 10  2024-08-07      76846.830         4.304091e+09
# 11  2024-08-08      76977.234         4.241669e+09
# 12  2024-08-09      74964.252         4.622448e+09
# 13  2024-08-10      71916.705         4.373161e+09
# 14  2024-08-11      71072.428         4.327987e+09
# 15  2024-08-12      70092.777         4.113969e+09
# 16  2024-08-13      68490.559         4.063107e+09
# ...

# %%
merged_df = pd.merge(open_interest_df,btc_df,left_on='Date',right_on='Date',how='left')
merged_df
# Out:
#           Date  Open Interest  Open Interest Value      Open      High  \
# 0   2024-07-28      86084.842         5.842012e+09  67896.49  68318.43
# 1   2024-07-29      85860.258         5.857181e+09  68249.88  70079.99
# 2   2024-07-30      84865.254         5.665371e+09  66784.68  67000.00
# 3   2024-07-31      82994.073         5.490838e+09  66188.00  66849.24
# 4   2024-08-01      82570.404         5.334197e+09  64628.01  65659.78
# 5   2024-08-02      87192.052         5.696161e+09  65354.02  65596.14
# 6   2024-08-03      87796.487         5.398053e+09  61498.34  62198.22
# 7   2024-08-04      85283.126         5.175372e+09  60697.99  61117.63
# 8   2024-08-05      88098.464         5.121965e+09  58161.00  58305.59
# 9   2024-08-06      75212.503         4.060142e+09  54018.82  57040.99
# 10  2024-08-07      76846.830         4.304091e+09  56022.00  57736.05
# 11  2024-08-08      76977.234         4.241669e+09  55133.76  62745.14
# ...

# %%
merged_df.to_csv('merged_open_interest_to_btc.csv', index=False)

# Plot BTC Price on the primary y-axis
fig, ax1 = plt.subplots(figsize=(14, 7))
ax1.set_xlabel('DateTime')
ax1.set_ylabel('BTC Price (USD)', color='tab:blue')
ax1.plot(merged_df['Date'], merged_df['BTC Price'], color='tab:blue', label='BTC Price')
ax1.tick_params(axis='y', labelcolor='tab:blue')

# Create a secondary y-axis for the Open Interest
ax2 = ax1.twinx()
ax2.set_ylabel('Open Interest', color='tab:orange')
ax2.plot(merged_df['Date'], merged_df['Open Interest'], color='tab:orange', label='Open Interest')
ax2.tick_params(axis='y', labelcolor='tab:orange')

# Title and legends
plt.title('Open Interest and BTC Price Over Time')
fig.tight_layout()  # Adjust layout to make room for the labels
plt.show()
